# %% [markdown]
# # chapter 1. 파이선
#
# - 장점 : 쉬움
# - 단점, C 언어 대비 느림 10배~350배 정도

# %% [markdown]
# ## 프로그래밍 용어
#
# ![alt text](appendix/image.png)

# %% [markdown]
# ### 문장statement
# - 실행할 수 있는 코드의 최소 단위

# %%
 # 실행되는 모든 한 줄 코드는 문장입니다. 
print("Python Programming") # 문장
10 + 20  # 문장
# Out:
# Python Programming
# 30

# %% [markdown]
# ### 표현식 Expression
# -  어떠한 값을 만들어 내는 간단한 코드

# %% [markdown]
# ### 키워드keyword
# - 특별한 의미가 부여된 단어로 파이썬이 만들어질 때 이미 사용하겠다고 예약해 놓은 것
# - 변수명으로 설정 불가

# %%
# 파이썬에서 사용하는 키워드
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### 식별자  identifier
# -  프로그래밍 언어에서 이름을 붙일 때 사용하는 단어입니다. 주로 변수 또는 함수 이름등으로 쓰임
# - 사실 클래스, 함수, 변수 명은 사용자가 맘대로 해도 되긴 하지만, 어느정도 규칙을 지키기 위해 아래와 같은 규칙이 있으니 알아는 둘것
# -  기본적으로 다음과 같은 규칙을 지켜 만들어야 합니다.\
#  • 키워드를사용하면 안 됩니다.\
#  • 특수 문자는 언더 바(_)만 허용됩니다.\
#  • 숫자로시작하면 안 됩니다.\
#  • 공백을 포함할 수 없습니다
#
#
#  ![alt text](appendix/image-1.png)
#
#
#  ![alt text](appendix/image-2.png)

# %% [markdown]
# ### 주석
# - 코드에 설명 넣는거
# - `#` 이나 `''' '''` 사이에 넣어서 코드 설명 산입

# %% [markdown]
# ### 연산자, 자료
# - 연산자는 스스로 값이 되는 것은 아니고 값과 값 사이에 무언가 기능을 적용할 때 사용하는 것을 말함 즉 `+`, `-` 같이 단독으로 못쓰는거
# -

# %% [markdown]
# ### return, print()의 차이

# %%
## output.py

print('# 하나만 출력')
print("HeUo Python Programming...!")
print()
# 여러 개를 출력합니다.
print("# 여러 개를 출력합니다.")
print(10, 20, 30, 40, 50)
print("안녕하세요", "저의", "이름은", "윤인성입니다!")
print()
# 아무것도 입력하지 않으면 단순하게 줄바꿈합니다.
print("# 아무것도 출력하지 않습니다.")
print("— 확인 전용선 ---")
print()
print()
print("— 확인 전용선 ---")
# Out:
# # 하나만 출력
# HeUo Python Programming...!
#
# # 여러 개를 출력합니다.
# 10 20 30 40 50
# 안녕하세요 저의 이름은 윤인성입니다!
#
# # 아무것도 출력하지 않습니다.
# — 확인 전용선 ---
#
#
# — 확인 전용선 ---

# %% [markdown]
# - 상기 파일을 파이썬 스크립트인 `.py` 확장자의 파일로 저장후 파이썬이나 리눅스 내 파이썬 명령어로 실행 가능

# %% [markdown]
# # chapter 2 자료형, 문자열
# - 프로그래밍에서는 프로그램이 처리할 수 있는 모든 것을 자료data 라고 부름
#
# - 예시\
#  • 카메라로 사진을 찍으면 사진이 자료이고, 이를 카메라에 저장하는 것이 처리입니다.\
#  • 카카오톡으로 친구에게 사진과 함께 “여기 어때?”라는 메시지를 보냈다면 사진과 메시지가 자료이고, 이를 친구에게 전송하는 것이 처리입니다.\
#  • 게임에서 경험치를 얻었다면 경험치가 자료이고, 경험치를 증가시키는 것이 처리입니다

# %% [markdown]
# ## 자료형 종류
#  • 문자열 string： 메일 제목, 메시지 내용 등 캐릭터 형태 안녕하세요", "Hello World"\
#  • 숫자형 number: 물건의 가격, 학생의 성적 등 캐릭터 형태 52, 273, 103.32\
#  • 불린 boolean： 친구의 로그인 상태 등, 논리 연산자 True, False\
#
#  - Data type 확인시 `type()` 함수 사용

# %%
print(type("안녕하세요"))
print(type(27.3))
print(type(27))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>

# %% [markdown]
# ### 문자열
# #### 문자열 만들기
# - `\`를 활용할것
# - `\t`탭
# - `\n` 줄바꿈
# - (`\`자체를 문자로 넣고 싶을 때) `\\`

# %%
print("안녕하세요")
print('안녕하세요')

# 따옴표 넣고 싶을 때
# print(""안녕하세요"라고 말하면 어떻게 될까?") # 오류 코드
print("'안녕하세요'라고 말하자")
print('"안녕하세요"라고 말하자')
print("\"안녕하세요\"라고 말하자")
print('\'안녕하세요\'라고 말하자')
print("\\")
# Out:
# 안녕하세요
# 안녕하세요
# '안녕하세요'라고 말하자
# "안녕하세요"라고 말하자
# "안녕하세요"라고 말하자
# '안녕하세요'라고 말하자
# \

# %%
# 이스케이프
print("이름\t나이\t지역")
print("윤인성\t25\t 강서구")
print("윤아린\t24\t 강서구")
print("구름\t3\t 강서구")
# Out:
# 이름	나이	지역
# 윤인성	25	 강서구
# 윤아린	24	 강서구
# 구름	3	 강서구

# %%
print("동해물과 백두산이 마르고 닳도록\n하느님이 보우하사 우리나라 만세\n무궁화 삼천리 화려강산 대한사람\n대한으로 길이 보전하세")
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려강산 대한사람
# 대한으로 길이 보전하세

# %%
print("""동해물과 백두산이 마르고 닳도록
하느님이 보우하사 우리나라 만세
무궁화 삼천리 화려강산 대한사람
대한으로 길이 보전하세""")

print("""\
동해물과 백두산이 마르고 닳도록
하느님이 보우하사 우리나라 만세
무궁화 삼천리 화려강산 대한사람
대한으로 길이 보전하세\ 
""")
# Out:
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려강산 대한사람
# 대한으로 길이 보전하세
# 동해물과 백두산이 마르고 닳도록
# 하느님이 보우하사 우리나라 만세
# 무궁화 삼천리 화려강산 대한사람
# 대한으로 길이 보전하세\

# %% [markdown]
# - 문자열도 더하기 빼기 곱하기 등 가능
# - 단 문자열끼리만, 숫자열 끼리만 가능

# %%
print("안녕" + "하세요")
print("안녕하세요", "!")
print("안녕"*3 + "하세요")
# Out:
# 안녕하세요
# 안녕하세요 !
# 안녕안녕안녕하세요

# %% [markdown]
# #### 인덱싱 기능 가능
# - 인덱싱 indexing : `[]` 활용해서 특정 위치에 있는 문자를 참조
# - 슬라이싱 slicing : `[:]` 연산자를 이용해 문자열 의 일부를 추출하는 것을
# - 문자열 길이 알고 싶으면 `len()`

# %%
print("너의 이름은 뭐냐 대체")
print("너의 이름은 뭐냐 대체"[0])
print("너의 이름은 뭐냐 대체"[1])
print("너의 이름은 뭐냐 대체"[2])
print("너의 이름은 뭐냐 대체"[3])
print("너의 이름은 뭐냐 대체"[4])
print("너의 이름은 뭐냐 대체"[5])
print("너의 이름은 뭐냐 대체"[-1])
print("너의 이름은 뭐냐 대체"[2:5])
print("너의 이름은 뭐냐 대체"[4:])
print("너의 이름은 뭐냐 대체"[:3])

# 문자열 길이 `len()`
print(len("너의 이름은 뭐냐 대체"))
print("너의 이름은 뭐냐 대체"[:3])
# Out:
# 너의 이름은 뭐냐 대체
# 너
# 의
#
# 이
# 름
# 은
# 체
#  이름
# 름은 뭐냐 대체
# 너의
# 12
# 너의

# %% [markdown]
# ####  lndexError(index out of range) 예외
# -  IndexError 예외는 리스트/문자열의 수를 넘는 요소/글자를 선택할 때 발생
# - 인덱스가 범위를 넘길때 발생

# %%
print("너의 이름은 뭐냐 대체"[15])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print("너의 이름은 뭐냐 대체"[15])
#
# IndexError: string index out of range

# %% [markdown]
# ### 숫자형
# #### 숫자형 종류
#  • 정수 integer：0, 1, 273, -52
#  • 실수 (부동 소수점) floating point： 0.0, 52.273, -1.2
#
# -  0은 소수점이 없는 숫자이고, 0.0은 소수점이 있는 숫자

# %%
print(type(52))
print(type(52.0))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# - 파이썬으로 만들어진 수학 연산, 인공지능 알고리즘을 보면 0.52273e2 혹은 0.52273E2 등의 특이한 숫자 표현을 볼 수있습니다. 이는 파이썬에서 부동 소수점을 지수승으로 표현하는 방법

# %%
print(0.52273e2)
print(0.52273e-2)
# Out:
# 52.273
# 0.0052273

# %% [markdown]
# #### 연산자 종류
# - \+
# - \-
# - \*
# - \/
# - // : 나누고 정수 부분만 남김
# - % : 나누고 나머지만 구함
# - ** : 제곱
#
# 연산 우선자는 괄호안에 먼저, 없으면 곱하기 나누기 먼저,

# %%
print("5 % 2 =", f"{5%2}")
print("5 % 2 =" + f"{5%2}")
# Out:
# 5 % 2 = 1
# 5 % 2 =1

# %%
print("안녕" + "하세요" * 3)
print(("안녕" + "하세요") * 3)
print("안녕" + ("하세요" * 3))
# Out:
# 안녕하세요하세요하세요
# 안녕하세요안녕하세요안녕하세요
# 안녕하세요하세요하세요

# %% [markdown]
# #### 타입 에러
# - 서로 다른 자료를 연산하면 TypeError라는 예외가 발생

# %%
string = "문자열"
number = 273
string + number
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 string = "문자열"
#       2 number = 273
# ----> 3 string + number
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## 변수, 입력
# - 변수는 값을 저장할 때 사용하는 식별자
# - 코드는 상기 참고

# %% [markdown]
# #### 다른 언어들
# -  C, C++, 자바, C# 등에서는 변수를 사용할 때 변수의 자료형을 미리 선언
# - 아래 처럼 선언 해야함
# ```C
# int pi
# ```

# %% [markdown]
# ### 복합 대입 연산자
# #### 숫자
# += : 숫자 덧셈 후 대입 \
# -= : 숫자 뺄셈 후 대입 \
# *= : 숫자 곱셈 후 대입 \
# /= : 숫자 나눗셈 후 대입 \
# %= : 숫자 나머지 구한 후 대입 \
# **= : 숫자 제곱 후 대입 \
#
# #### 문자
# += : 문자열 연결 후 대입 \
# *= : 문자열 반복 후 대입

# %%
number = 0
print(number)
number += 10
print(number)
number -= 5
print(number)
# Out:
# 0
# 10
# 5

# %%
string = "안녕하세요"
print(string)
string += "!"
print(string)
string *= 3
print(string)
# Out:
# 안녕하세요
# 안녕하세요!
# 안녕하세요!안녕하세요!안녕하세요!

# %% [markdown]
# ### 사용자 입력 : `input()`

# %%
input("인사말을 입력하세요＞")
# Out:
# '하이하이'

# %% [markdown]
# - 주의점 아래 코드 참고
# - `input()`함수는 사용자가 어떤 자료형을 입력해도 결과는 무조건 문자열로 변환됨
# - 그렇기 때문에 숫자형으로 인풋값을 받고자 하는 경우 항상 문자열이기 때문에 입력받은 문자열을 숫자로 변환해야 숫자 연산에 활용할 수 있습니다.
# - 이걸 영어로는 캐스트 cast라고 부름
#
#  • int() 함수: 문자열을 int 자료형으로 변환합니다. int는 정수형을 의미합니다.
#  • float() 함수: 문자열을 float 자료형으로 변환합니다. float는 실수형 또는 부동 소수점을 의미 합니다.

# %%
number = input("숫자 입력하세요")
print(number)
print(type(number))
# Out:
# 123456
# <class 'str'>

# %%
data = input("입력해 주세요 >")

print("타입:", type(data))
# Out:
# 타입: <class 'str'>

# %% [markdown]
# ## 기타 다른 기능
# ### 문자열 `format()`
# - 두가지 방법 존재

# %%
string_a = "{}".format(10)
print("{}, {}, {}".format(10, 20, 88525))
print(string_a)
print(type(string_a))

"{}, {}, {}".format(10, 20, 88525, 30, 40)
"{}, {}, {}".format(10, 20)
# Out:
# 10, 20, 88525
# 10
# <class 'str'>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 7
#       4 print(type(string_a))
#       6 "{}, {}, {}".format(10, 20, 88525, 30, 40)
# ----> 7 "{}, {}, {}".format(10, 20)
#
# IndexError: Replacement index 2 out of range for positional args tuple

# %% [markdown]
# - 아래는 f-string 기능으로 포맷팅 하는법 (3.6버전 이상만 지원)

# %%
"3 + 4 = {}".format(3 + 4)
# Out:
# '3 + 4 = 7'

# %%
f"3 + 4 = {3+4}"
# Out:
# '3 + 4 = 7'

# %%
# 정수
output_a = "{:d}".format(52)

# 특정 칸에 출력
output_b = "{:5d}".format(52) # 5칸
output_c = "{:10d}".format(52) # 10칸

# 빈칸 0으로 채우기
output_d = "{:05d}" .format(52) # 양수
output_e = "{:05d}".format(-52)

print("# 기본")
print(output_a)
print("# 특정 칸에 출력하기")
print(output_b)
print(output_c)
print("# 빈칸을 0으로 채우기")
print(output_d)
print(output_e)
# Out:
# # 기본
# 52
# # 특정 칸에 출력하기
#    52
#         52
# # 빈칸을 0으로 채우기
# 00052
# -0052

# %% [markdown]
# ### 대소문자
# - `upper()` 함수는 문자열의 알파벳을 대문
# - `lower()` 함수는 싹다 소문자
#
#
# 문자열과 관련된 함수를 사용할 때 착각하는 것 중 하나가 `upper()` 함수와 `lower()` 함수를 사용하면 a의 문자열이 바뀔 것으로 생각하는데, 절대로 원본은 변하지 않는다는 것을 기억하세요. 이렇게 원본을 변화시키지 않는 함수를 비파괴적 함수라고 부릅니다. 이와 반대되는 파괴적 함수는 4장에서 배웁니다.

# %% [markdown]
# ### 문자열 양옆의 공백 제거하기: strip()
#
#  • `strip()`： 문자열 양옆의 공백을 제거합니다.
#  • `lstrip()`： 문자열 왼쪽의 공백을 제거합니다.
#  • `rstrip()`： 문자열 오른쪽의 공백을 제거합니다.

# %% [markdown]
# ### 문자열 데이터의 구성 파악
# - 주의할점:단순 확인 정도로 출력값은 boolean
#
#  • `isalnum()`： 문자열이 알파벳 또는 숫자로만 구성되어 있는지 확인합니다. \
#  • `isalpha()`： 문자열이 알파벳으로만구성되어 있는지 확인합니다. \
#  • `isidentifier()`: 문자열이 식별자로 사용할 수 있는 것인지 확인합니다. \
#  • `isdecimal()`： 문자열이 정수 형태인지 확인합니다. \
#  • `isdigit()`： 문자열이 숫자로 인식될 수 있는 것인지 확인합니다. \
#  • `isspace()`： 문자열이 공백으로만 구성되어 있는지 확인합니다. \
#  \
#  • `islower()`： 문자열이 소문자로만 구성되어 있는지 확인합니다. \
#  • `isupper()`： 문자열이 대문자로만 구성되어 있는지 확인합니다. \

# %% [markdown]
# ### 문자열 찾기
#  • find()： 왼쪽부터 차］서 처음 등장하는 위치를 찾습니다. \
#  • rfindO： 오른쪽부터 찾아서 처음 등장하는 위치를 찾습니다.

# %% [markdown]
# ### 문자열과 in 연산자
# - 문자열 내부에 어떤 문자열이 있는지 확인하려면 in 연산자를 사용

# %% [markdown]
# ### 문자열 자르기
# - `split()` : 문자열을 특정한 문자로 자를 때

# %% [markdown]
# # 도전 문제
# 구의 부피와 겉넓이를 구하는 프로그램을 만들어 보세요. 구의 부피와 겉넓이를 구하는 공식은 다음과 같습니다
#
# 구의 반지름을 $r$이라고 할 때
# 부피 = $\frac{4}{3}\pi r^3$ \
# 겉넓이 = $4\pi r^2$
#
# ```bash
# - 구의 반지름을 입력해주세요: 5
#  = 구의 부피는 523.5986666666666입니다.
#  = 구의 겉넓이는 314.1592입니다.

# %%
data = input("구의 반지름을 입력해주세요: ")
r = float(data)
volumn = 4/3 * 3.14159 * r**3
surface_area = 4 * 3.14159 * r**2
print(f"구의 부피는 {volumn}입니다.")
print(f"구의 겉넓이는 {surface_area}입니다.")
# Out:
# 구의 부피는 523.5983333333332입니다.
# 구의 겉넓이는 314.159입니다.

# %% [markdown]
# 피타고라스의 정리는 삼각형의 밑변, 높이, 빗변의 관계를 나타내는 공식입니다.
# $$
# a^2 + b^2 = c^2
# $$
#
# 빗변 C를 계산하려면 다음과 같은 공식을 사용합니다.
# $$
# c = \sqrt{a^2+b^2}
# $$
# 위 공식에 따라 파이썬으로 밑변과 높이를 입력하면 빗변의 길이를 구하는 프로그램

# %%
data1 = input("밑변의 길이를 입력해 주세요: ")
data2 = input("높이의 길이를 입력해 주세요: ")
d1 = float(data1)
d2 = float(data2)
print(f"빗변의 길이는 {(d1**2+d2**2)**(1/2)}입니다.")
# Out:
# 빗변의 길이는 5.0입니다.
